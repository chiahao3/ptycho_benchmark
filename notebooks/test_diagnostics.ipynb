# %%
import os

work_dir = "H:/workspace/ptycho_benchmark"

os.chdir(work_dir)
print("Current working dir: ", os.getcwd())
# Out:
# Current working dir:  H:\workspace\ptycho_benchmark

# %%
from scripts.diagnostics import print_system_info
print_system_info()
# Out:
# ### System information ###
# Platform: Windows-10-10.0.19045-SP0
# Operating System: Windows 10
# OS Version: 10.0.19045
# Machine: AMD64
# Processor: Intel64 Family 6 Model 85 Stepping 4, GenuineIntel
# Available CPU cores: 12
# Total Memory: 63.49 GB
# Available Memory: 30.86 GB
#
# ### GPU information ###
# --- PyTorch Backend ---
# CUDA Available: True
# CUDA Version: 11.8
# Available CUDA GPUs: ['Quadro P5000', 'Quadro P4000']
# CUDA Compute Capability: ['6.1', '6.1']
#   INFO: For torch.compile with Triton, you'll need CUDA GPU with Compute Capability >= 7.0.
#         In addition, Triton does not directly support Windows.
#         For Windows users, please follow the instruction and download `triton-windows` from https://github.com/woct0rdho/triton-windows.
# MIG (Multi-Instance GPU) mode = False
#   INFO: MIG splits a physical GPU into multiple GPU slices, but multiGPU does not support these MIG slices.
# ...
